# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
dataframe = pd.read_csv('Inference_Results_Paper1.csv')

# %%
dataframe['Inference']=np.log(dataframe['Inference'])

# %%
fig, axs = plt.subplots(2, 2, tight_layout=True)
ymax=math.ceil(dataframe[((dataframe['Model']=="ResNet")|(dataframe['Model']=="ResNext")|(dataframe['Model']=="FCN")|(dataframe['Model']=="DUC")) & ((dataframe['Device']=="Mobile") | (dataframe['Device']=="Edge") | (dataframe['Device']=="Cloud"))]['Inference'].max())
sns.boxplot(data=dataframe[(dataframe['Model']=="ResNet") & ((dataframe['Device']=="Mobile") | (dataframe['Device']=="Edge") | (dataframe['Device']=="Cloud"))],x="Device",y="Inference", ax=axs[0][0], linewidth=0.8)
axs[0][0].set_title('ResNet')
axs[0][0].set_ylabel('log(s)')
axs[0][0].set_ylim(([0, ymax]))
sns.boxplot(data=dataframe[(dataframe['Model']=="ResNext") & ((dataframe['Device']=="Mobile") | (dataframe['Device']=="Edge") | (dataframe['Device']=="Cloud"))],x="Device",y="Inference", ax=axs[0][1], linewidth=0.8)
axs[0][1].set_title('ResNext')
axs[0][1].set_ylabel('log(s)')
axs[0][1].set_ylim(([0, ymax]))
sns.boxplot(data=dataframe[(dataframe['Model']=="FCN") & ((dataframe['Device']=="Mobile") | (dataframe['Device']=="Edge") | (dataframe['Device']=="Cloud"))],x="Device",y="Inference", ax=axs[1][0], linewidth=0.8)
axs[1][0].set_title('FCN')
axs[1][0].set_ylabel('log(s)')
axs[1][0].set_ylim(([0, ymax]))
sns.boxplot(data=dataframe[(dataframe['Model']=="DUC") & ((dataframe['Device']=="Mobile") | (dataframe['Device']=="Edge") | (dataframe['Device']=="Cloud"))],x="Device",y="Inference", ax=axs[1][1], linewidth=0.8)
axs[1][1].set_title('DUC')
axs[1][1].set_ylabel('log(s)')
axs[1][1].set_ylim(([0, ymax]))
plt.show()
fig.savefig('img_rq1_results.pdf', bbox_inches='tight',format='pdf')

# %%
x_labels = ['E','ME', 'M','EC', 'MC', 'C']
fig, axs = plt.subplots(2, 2, tight_layout=True)
ymax=math.ceil(dataframe[((dataframe['Model']=="ResNet")|(dataframe['Model']=="ResNext")|(dataframe['Model']=="FCN")|(dataframe['Model']=="DUC")) & ((dataframe['Device']=="Mobile") | (dataframe['Device']=="Edge") | (dataframe['Device']=="Cloud") | (dataframe['Device']=="Mobile-Edge") | (dataframe['Device']=="Edge-Cloud") | (dataframe['Device']=="Mobile-Cloud"))]['Inference'].max())
sns.boxplot(data=dataframe[(dataframe['Model']=="ResNet") & ((dataframe['Device']=="Mobile-Edge") | (dataframe['Device']=="Edge-Cloud") | (dataframe['Device']=="Mobile-Cloud") | (dataframe['Device']=="Mobile") | (dataframe['Device']=="Edge") | (dataframe['Device']=="Cloud"))],x="Device",y="Inference", ax=axs[0][0], linewidth=0.8,order=["Edge","Mobile-Edge","Mobile", "Edge-Cloud","Mobile-Cloud","Cloud"])
axs[0][0].set_xticklabels(x_labels)  # Set the new x labels
axs[0][0].set_title('ResNet')
axs[0][0].set_ylabel('log(s)')
axs[0][0].set_ylim(([0, ymax]))
sns.boxplot(data=dataframe[(dataframe['Model']=="ResNext") & ((dataframe['Device']=="Mobile-Edge") | (dataframe['Device']=="Edge-Cloud") | (dataframe['Device']=="Mobile-Cloud") | (dataframe['Device']=="Mobile") | (dataframe['Device']=="Edge") | (dataframe['Device']=="Cloud"))],x="Device",y="Inference", ax=axs[0][1], linewidth=0.8,order=["Edge","Mobile-Edge","Mobile", "Edge-Cloud","Mobile-Cloud","Cloud"])
axs[0][1].set_xticklabels(x_labels)  # Set the new x labels
axs[0][1].set_title('ResNext')
axs[0][1].set_ylabel('log(s)')
axs[0][1].set_ylim(([0, ymax]))
sns.boxplot(data=dataframe[(dataframe['Model']=="FCN") & ((dataframe['Device']=="Mobile-Edge") | (dataframe['Device']=="Edge-Cloud") | (dataframe['Device']=="Mobile-Cloud") | (dataframe['Device']=="Mobile") | (dataframe['Device']=="Edge") | (dataframe['Device']=="Cloud"))],x="Device",y="Inference", ax=axs[1][0], linewidth=0.8,order=["Edge","Mobile-Edge","Mobile", "Edge-Cloud","Mobile-Cloud","Cloud"])
axs[1][0].set_xticklabels(x_labels)  # Set the new x labels
axs[1][0].set_title('FCN')
axs[1][0].set_ylabel('log(s)')
axs[1][0].set_ylim(([0, ymax]))
sns.boxplot(data=dataframe[(dataframe['Model']=="DUC") & ((dataframe['Device']=="Mobile-Edge") | (dataframe['Device']=="Edge-Cloud") | (dataframe['Device']=="Mobile-Cloud") | (dataframe['Device']=="Mobile") | (dataframe['Device']=="Edge") | (dataframe['Device']=="Cloud"))],x="Device",y="Inference", ax=axs[1][1], linewidth=0.8,order=["Edge","Mobile-Edge","Mobile", "Edge-Cloud","Mobile-Cloud","Cloud"])
axs[1][1].set_xticklabels(x_labels)  # Set the new x labels
axs[1][1].set_title('DUC')
axs[1][1].set_ylabel('log(s)')
axs[1][1].set_ylim(([0, ymax]))
plt.show()
fig.savefig('img_r4_results.pdf', bbox_inches='tight',format='pdf')

# %%
x_labels = ['E','ME', 'M','EC', 'MC', 'C']
fig, axs = plt.subplots(2, 2, tight_layout=True)
ymax=math.ceil(dataframe[((dataframe['Model']=="ResNet Quantize EarlyExit")|(dataframe['Model']=="ResNext Quantize EarlyExit")|(dataframe['Model']=="FCN Quantize EarlyExit")|(dataframe['Model']=="DUC Quantize EarlyExit")) & ((dataframe['Device']=="Mobile") | (dataframe['Device']=="Edge") | (dataframe['Device']=="Cloud") | (dataframe['Device']=="Mobile-Edge") | (dataframe['Device']=="Edge-Cloud") | (dataframe['Device']=="Mobile-Cloud"))]['Inference'].max())
sns.boxplot(data=dataframe[(dataframe['Model']=="ResNet Quantize EarlyExit") & ((dataframe['Device']=="Mobile-Edge") | (dataframe['Device']=="Edge-Cloud") | (dataframe['Device']=="Mobile-Cloud") | (dataframe['Device']=="Mobile") | (dataframe['Device']=="Edge") | (dataframe['Device']=="Cloud"))],x="Device",y="Inference", ax=axs[0][0], linewidth=0.8,order=["Edge","Mobile-Edge","Mobile", "Edge-Cloud","Mobile-Cloud","Cloud"])
axs[0][0].set_xticklabels(x_labels)  # Set the new x labels
axs[0][0].set_title('ResNet')
axs[0][0].set_ylabel('log(s)')
axs[0][0].set_ylim(([0, ymax]))
sns.boxplot(data=dataframe[(dataframe['Model']=="ResNext Quantize EarlyExit") & ((dataframe['Device']=="Mobile-Edge") | (dataframe['Device']=="Edge-Cloud") | (dataframe['Device']=="Mobile-Cloud") | (dataframe['Device']=="Mobile") | (dataframe['Device']=="Edge") | (dataframe['Device']=="Cloud"))],x="Device",y="Inference", ax=axs[0][1], linewidth=0.8,order=["Edge","Mobile-Edge","Mobile", "Edge-Cloud","Mobile-Cloud","Cloud"])
axs[0][1].set_xticklabels(x_labels)  # Set the new x labels
axs[0][1].set_title('ResNext')
axs[0][1].set_ylabel('log(s)')
axs[0][1].set_ylim(([0, ymax]))
sns.boxplot(data=dataframe[(dataframe['Model']=="FCN Quantize EarlyExit") & ((dataframe['Device']=="Mobile-Edge") | (dataframe['Device']=="Edge-Cloud") | (dataframe['Device']=="Mobile-Cloud") | (dataframe['Device']=="Mobile") | (dataframe['Device']=="Edge") | (dataframe['Device']=="Cloud"))],x="Device",y="Inference", ax=axs[1][0], linewidth=0.8,order=["Edge","Mobile-Edge","Mobile", "Edge-Cloud","Mobile-Cloud","Cloud"])
axs[1][0].set_xticklabels(x_labels)  # Set the new x labels
axs[1][0].set_title('FCN')
axs[1][0].set_ylabel('log(s)')
axs[1][0].set_ylim(([0, ymax]))
sns.boxplot(data=dataframe[(dataframe['Model']=="DUC Quantize EarlyExit") & ((dataframe['Device']=="Mobile-Edge") | (dataframe['Device']=="Edge-Cloud") | (dataframe['Device']=="Mobile-Cloud") | (dataframe['Device']=="Mobile") | (dataframe['Device']=="Edge") | (dataframe['Device']=="Cloud"))],x="Device",y="Inference", ax=axs[1][1], linewidth=0.8,order=["Edge","Mobile-Edge","Mobile", "Edge-Cloud","Mobile-Cloud","Cloud"])
axs[1][1].set_xticklabels(x_labels)  # Set the new x labels
axs[1][1].set_title('DUC')
axs[1][1].set_ylabel('log(s)')
axs[1][1].set_ylim(([0, ymax]))
plt.show()
fig.savefig('img_r5_results.pdf', bbox_inches='tight',format='pdf')

# %%
x_labels=['M','E','C','ME']
fig, axs = plt.subplots(2, 2, tight_layout=True)
data1=dataframe[((dataframe['Model']=="ResNet") | (dataframe['Model']=="ResNet EarlyExit") | (dataframe['Model']=="ResNet Quantize") | (dataframe['Model']=="ResNet Quantize EarlyExit") ) & ((dataframe['Device']=="Mobile") | (dataframe['Device']=="Edge") | (dataframe['Device']=="Cloud") | (dataframe['Device']=="Mobile-Edge"))]
data2=dataframe[((dataframe['Model']=="ResNext") | (dataframe['Model']=="ResNext EarlyExit") | (dataframe['Model']=="ResNext Quantize") | (dataframe['Model']=="ResNext Quantize EarlyExit")) & ((dataframe['Device']=="Mobile") | (dataframe['Device']=="Edge") | (dataframe['Device']=="Cloud") | (dataframe['Device']=="Mobile-Edge"))]
data3=dataframe[((dataframe['Model']=="FCN") | (dataframe['Model']=="FCN EarlyExit") | (dataframe['Model']=="FCN Quantize") | (dataframe['Model']=="FCN Quantize EarlyExit")) & ((dataframe['Device']=="Mobile") | (dataframe['Device']=="Edge") | (dataframe['Device']=="Cloud") | (dataframe['Device']=="Mobile-Edge"))]
data4=dataframe[((dataframe['Model']=="DUC") | (dataframe['Model']=="DUC EarlyExit") | (dataframe['Model']=="DUC Quantize") | (dataframe['Model']=="DUC Quantize EarlyExit")) & ((dataframe['Device']=="Mobile") | (dataframe['Device']=="Edge") | (dataframe['Device']=="Cloud") | (dataframe['Device']=="Mobile-Edge"))]
ymax=math.ceil(max(data1['Inference'].max(), data2['Inference'].max(), data3['Inference'].max(), data4['Inference'].max()))
sns.boxplot(data=data1,x="Device",y="Inference",hue="Model",ax=axs[0][0], linewidth=0.8,hue_order=["ResNet","ResNet Quantize","ResNet EarlyExit","ResNet Quantize EarlyExit"],order=["Mobile","Edge","Cloud","Mobile-Edge"])
axs[0][0].set_title('ResNet')
axs[0][0].set_ylabel('log(s)')
axs[0][0].set_ylim(([0, ymax]))
axs[0][0].set_xticklabels(x_labels)
handles,_=axs[0][0].get_legend_handles_labels()
fig.legend(handles,["Identity","Quantize","EarlyExit","Quantize EarlyExit"],loc='upper center',ncol=4,fontsize=10,bbox_to_anchor=(0.5, 1.07))
sns.boxplot(data=data2,x="Device",y="Inference",hue="Model",ax=axs[0][1], linewidth=0.8,hue_order=["ResNext","ResNext Quantize","ResNext EarlyExit","ResNext Quantize EarlyExit"],order=["Mobile","Edge","Cloud","Mobile-Edge"])
axs[0][1].set_title('ResNext')
axs[0][1].set_ylabel('log(s)')
axs[0][1].set_ylim(([0, ymax]))
axs[0][1].set_xticklabels(x_labels)
sns.boxplot(data=data3,x="Device",y="Inference",hue="Model",ax=axs[1][0], linewidth=0.8,hue_order=["FCN","FCN Quantize","FCN EarlyExit","FCN Quantize EarlyExit"],order=["Mobile","Edge","Cloud","Mobile-Edge"])
axs[1][0].set_title('FCN')
axs[1][0].set_ylabel('log(s)')
axs[1][0].set_ylim(([0, ymax]))
axs[1][0].set_xticklabels(x_labels)
sns.boxplot(data=data4,x="Device",y="Inference",hue="Model",ax=axs[1][1], linewidth=0.8,hue_order=["DUC","DUC Quantize","DUC EarlyExit","DUC Quantize EarlyExit"],order=["Mobile","Edge","Cloud","Mobile-Edge"])
axs[1][1].set_title('DUC')
axs[1][1].set_ylabel('log(s)')
axs[1][1].set_ylim(([0, ymax]))
axs[1][1].set_xticklabels(x_labels)
axs[0][0].get_legend().remove()
axs[0][1].get_legend().remove()
axs[1][0].get_legend().remove()
axs[1][1].get_legend().remove()
plt.show()
fig.savefig('img_rq2_rq3_rq4_rq5_results.pdf', bbox_inches='tight',format='pdf')

# %%
import numpy as np
import pandas as pd
import scipy
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
mean_values=[]
median_values=[]
subjects=["ResNet","ResNext","FCN","DUC"]
devices=["Mobile","Edge","Cloud","Mobile-Edge","Mobile-Cloud","Edge-Cloud"]
data=pd.read_csv('Inference_Results_Paper1.csv')
data['Inference']=np.log(data['Inference'])
accuracy=pd.read_csv('accuracy.csv')
df = pd.DataFrame(columns=['Inference Latency(s)','Top5(%)', 'Top1(%)','mIOU(%)','Device', 'Model','Subject'])
for subject in subjects:
    models=[subject,subject+" EarlyExit",subject+ " Quantize",subject+" Quantize EarlyExit"]
    for i in range(len(devices)):
        for j in range(len(models)):
            median=np.median(data[(data['Device']==devices[i]) & (data['Model']==models[j])]['Inference'])
            if subject in ["FCN","DUC"]:
                miou=np.max(accuracy[accuracy['Model']==models[j]]['miou'])
                df = df._append({'Inference Latency(s)': median, 'Top5(%)':np.nan,'Top1(%)':np.nan,'mIOU(%)':miou,'Device': devices[i],'Model': models[j],'Subject':subject}, ignore_index=True)
            if subject in ["ResNet","ResNext"]:
                top5=np.max(accuracy[accuracy['Model']==models[j]]['top5'])
                top1=np.max(accuracy[accuracy['Model']==models[j]]['top1'])
                df = df._append({'Inference Latency(s)': median, 'Top5(%)':top5,'Top1(%)':top1,'mIOU(%)':np.nan,'Device': devices[i],'Model': models[j],'Subject':subject}, ignore_index=True)
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\ProgramData\anaconda3\Lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\ProgramData\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\ProgramData\anaconda3\Lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\ProgramData\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\ProgramData\anaconda3\Lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
# ...

# %%
from matplotlib import markers
import matplotlib.pyplot as plt
import seaborn as sns
fig, axs = plt.subplots(3, 4, tight_layout=True,figsize=(14,6))
sns.scatterplot(data=df[df['Subject']=='ResNet'], x="Inference Latency(s)", y="Top5(%)", hue="Device", ax=axs[0][0], marker="o",hue_order=["Mobile","Edge","Cloud","Mobile-Edge","Edge-Cloud","Mobile-Cloud"])
handles,labels=axs[0][0].get_legend_handles_labels()
fig.legend(handles,labels,loc='upper center',ncol=6,fontsize=10,bbox_to_anchor=(0.5, 1.14))
axs[0][0].set_title('ResNet')
axs[0][0].set_ylabel('Top5(%)')
axs[0][0].set_xlabel('log(s)')
axs[0][0].set_ylim(([0, 100]))
sns.scatterplot(data=df[df['Subject']=='ResNet'], x="Inference Latency(s)", y="Top5(%)", hue="Model", ax=axs[0][1], marker="s",hue_order=["ResNet","ResNet Quantize","ResNet EarlyExit","ResNet Quantize EarlyExit"])
handles,_=axs[0][1].get_legend_handles_labels()
marker_shape = "s"
handles = [plt.Line2D([], [], marker=marker_shape, linestyle="None", color=h.get_facecolor()[0]) for h in handles]
fig.legend(handles,["Identity","Quantize","EarlyExit","Quantize EarlyExit"],loc='upper center',ncol=8,fontsize=10,bbox_to_anchor=(0.5, 1.07))
axs[0][1].set_title('ResNet')
axs[0][1].set_ylabel('Top5(%)')
axs[0][1].set_xlabel('log(s)')
axs[0][1].set_ylim(([0, 100]))
sns.scatterplot(data=df[df['Subject']=='ResNext'], x="Inference Latency(s)", y="Top5(%)", hue="Device", ax=axs[0][2], marker="o",hue_order=["Mobile","Edge","Cloud","Mobile-Edge","Edge-Cloud","Mobile-Cloud"])
axs[0][2].set_title('ResNext')
axs[0][2].set_ylabel('Top5(%)')
axs[0][2].set_xlabel('log(s)')
axs[0][2].set_ylim(([0, 100]))
sns.scatterplot(data=df[df['Subject']=='ResNext'], x="Inference Latency(s)", y="Top5(%)", hue="Model", ax=axs[0][3], marker="s",hue_order=["ResNext","ResNext Quantize","ResNext EarlyExit","ResNext Quantize EarlyExit"])
axs[0][3].set_title('ResNext')
axs[0][3].set_ylabel('Top5(%)')
axs[0][3].set_xlabel('log(s)')
axs[0][3].set_ylim(([0, 100]))
sns.scatterplot(data=df[df['Subject']=='ResNet'], x="Inference Latency(s)", y="Top1(%)", hue="Device", ax=axs[1][0], marker="o",hue_order=["Mobile","Edge","Cloud","Mobile-Edge","Edge-Cloud","Mobile-Cloud"])
axs[1][0].set_title('ResNet')
axs[1][0].set_ylabel('Top1(%)')
axs[1][0].set_xlabel('log(s)')
axs[1][0].set_ylim(([0, 100]))
sns.scatterplot(data=df[df['Subject']=='ResNet'], x="Inference Latency(s)", y="Top1(%)", hue="Model", ax=axs[1][1], marker="s",hue_order=["ResNet","ResNet Quantize","ResNet EarlyExit","ResNet Quantize EarlyExit"])
axs[1][1].set_title('ResNet')
axs[1][1].set_ylabel('Top1(%)')
axs[1][1].set_xlabel('log(s)')
axs[1][1].set_ylim(([0, 100]))
sns.scatterplot(data=df[df['Subject']=='ResNext'], x="Inference Latency(s)", y="Top1(%)", hue="Device", ax=axs[1][2], marker="o",hue_order=["Mobile","Edge","Cloud","Mobile-Edge","Edge-Cloud","Mobile-Cloud"])
axs[1][2].set_title('ResNext')
axs[1][2].set_ylabel('Top5(%)')
axs[1][2].set_xlabel('log(s)')
axs[1][2].set_ylim(([0, 100]))
sns.scatterplot(data=df[df['Subject']=='ResNext'], x="Inference Latency(s)", y="Top1(%)", hue="Model", ax=axs[1][3], marker="s",hue_order=["ResNext","ResNext Quantize","ResNext EarlyExit","ResNext Quantize EarlyExit"])
axs[1][3].set_title('ResNext')
axs[1][3].set_ylabel('Top5(%)')
axs[1][3].set_xlabel('log(s)')
axs[1][3].set_ylim(([0, 100]))
sns.scatterplot(data=df[df['Subject']=='FCN'], x="Inference Latency(s)", y="mIOU(%)", hue="Device", ax=axs[2][0], marker="o",hue_order=["Mobile","Edge","Cloud","Mobile-Edge","Edge-Cloud","Mobile-Cloud"])
axs[2][0].set_title('FCN')
axs[2][0].set_ylabel('mIOU(%)')
axs[2][0].set_xlabel('log(s)')
axs[2][0].set_ylim(([0, 100]))
sns.scatterplot(data=df[df['Subject']=='FCN'], x="Inference Latency(s)", y="mIOU(%)", hue="Model", ax=axs[2][1], marker="s",hue_order=["FCN","FCN Quantize","FCN EarlyExit","FCN Quantize EarlyExit"])
axs[2][1].set_title('FCN')
axs[2][1].set_ylabel('mIOU(%)')
axs[2][1].set_xlabel('log(s)')
axs[2][1].set_ylim(([0, 100]))
sns.scatterplot(data=df[df['Subject']=='DUC'], x="Inference Latency(s)", y="mIOU(%)", hue="Device", ax=axs[2][2], marker="o",hue_order=["Mobile","Edge","Cloud","Mobile-Edge","Edge-Cloud","Mobile-Cloud"])
axs[2][2].set_title('DUC')
axs[2][2].set_ylabel('mIOU(%)')
axs[2][2].set_xlabel('log(s)')
axs[2][2].set_ylim(([0, 100]))
sns.scatterplot(data=df[df['Subject']=='DUC'], x="Inference Latency(s)", y="mIOU(%)", hue="Model", ax=axs[2][3], marker="s",hue_order=["DUC","DUC Quantize","DUC EarlyExit","DUC Quantize EarlyExit"])
axs[2][3].set_title('DUC')
axs[2][3].set_ylabel('mIOU(%)')
axs[2][3].set_xlabel('log(s)')
axs[2][3].set_ylim(([0, 100]))
axs[0][0].get_legend().remove()
axs[0][1].get_legend().remove()
axs[0][2].get_legend().remove()
axs[0][3].get_legend().remove()
axs[1][0].get_legend().remove()
axs[1][1].get_legend().remove()
axs[1][2].get_legend().remove()
axs[1][3].get_legend().remove()
axs[2][0].get_legend().remove()
axs[2][1].get_legend().remove()
axs[2][2].get_legend().remove()
axs[2][3].get_legend().remove()
plt.show()
